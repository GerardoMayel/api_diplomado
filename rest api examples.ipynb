# %% [markdown]
# Estos ejemplos de peticiones REST API fueron generados usando la aplicación de Postman.

# %% [markdown]
# ## REST API `cURL`

# %%
# !curl --location --request POST 'https://gorest.co.in/public/v2/users' --header 'Content-Type: application/json' --header 'Authorization: Bearer 943789d80546535aef167af0afc0b8abdbc358e76308bafd10ba03f7f331f64e' --data-raw '{"name": "Fernando Garcia", "gender": "male", "email": "fer.g@test.com", "status": "active"}'
# Out:
# {"id":5707339,"name":"Fernando Garcia","email":"fer.g@test.com","gender":"male","status":"active"}

# %%
# !echo Hola
# Out:
# Hola

# %% [markdown]
# ## REST API Python `POST`

# %%
import http.client
import json

conn = http.client.HTTPSConnection("gorest.co.in")
payload = json.dumps({
  "name": "Rocio Salgado",
  "gender": "male",
  "email": "roci2o.s@test.com",
  "status": "active"
})
headers = {
  'Content-Type': 'application/json',
  'Authorization': 'Bearer 8d498a7ca097f8b932a431a821599c4404b5ecc058c7ffe682846ed3cd3b2bfc'
}
conn.request("POST", "/public/v2/users", payload, headers)
#conn.request("GET", "/public/v2/users", headers)
res = conn.getresponse()
data = res.read()
print(data.decode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# SSLCertVerificationError                  Traceback (most recent call last)
# /Users/mayel/diplomado/api_diplomado/rest api examples.ipynb Cell 6 line 1
#       <a href='vscode-notebook-cell:/Users/mayel/diplomado/api_diplomado/rest%20api%20examples.ipynb#W5sZmlsZQ%3D%3D?line=4'>5</a> payload = json.dumps({
#       <a href='vscode-notebook-cell:/Users/mayel/diplomado/api_diplomado/rest%20api%20examples.ipynb#W5sZmlsZQ%3D%3D?line=5'>6</a>   "name": "Rocio Salgado",
#       <a href='vscode-notebook-cell:/Users/mayel/diplomado/api_diplomado/rest%20api%20examples.ipynb#W5sZmlsZQ%3D%3D?line=6'>7</a>   "gender": "male",
#       <a href='vscode-notebook-cell:/Users/mayel/diplomado/api_diplomado/rest%20api%20examples.ipynb#W5sZmlsZQ%3D%3D?line=7'>8</a>   "email": "roci2o.s@test.com",
# ...

# %% [markdown]
# ## REST API Python `GET`

# %%
import requests
import json

url = "https://gorest.co.in/public/v2/users"

payload = json.dumps({
  "name": "Rocio Salgado",
  "gender": "male",
  "email": "rocio.s@test.com",
  "status": "active"
})
headers = {
  'Authorization': 'Bearer 8d498a7ca097f8b932a431a821599c4404b5ecc058c7ffe682846ed3cd3b2bfc',
  'Content-Type': 'application/json'
}

#response = requests.request("POST", url, headers=headers, data=payload)
response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# [{"id":5707258,"name":"Aanandaswarup Somayaji","email":"aanandaswarup_somayaji@auer.test","gender":"female","status":"active"},{"id":5707257,"name":"Deepali Mehra","email":"deepali_mehra@strosin.test","gender":"female","status":"inactive"},{"id":5707256,"name":"Aagney Tandon","email":"tandon_aagney@pollich.example","gender":"female","status":"inactive"},{"id":5707255,"name":"Rukhmani Mehrotra","email":"rukhmani_mehrotra@beatty-parker.example","gender":"male","status":"inactive"},{"id":5707254,"name":"Vaidehi Trivedi","email":"vaidehi_trivedi@moen-daugherty.example","gender":"male","status":"inactive"},{"id":5707253,"name":"Aanandaswarup Namboothiri PhD","email":"aanandaswarup_phd_namboothiri@will.test","gender":"female","status":"active"},{"id":5707252,"name":"Hiranya Asan","email":"hiranya_asan@rau.example","gender":"female","status":"active"},{"id":5707251,"name":"Ashlesh Kapoor","email":"kapoor_ashlesh@hessel.test","gender":"male","status":"active"},{"id":5707250,"name":"Trilokana
# ...

# %%
import requests
import json

url = "https://gorest.co.in/public/v2/users/5707339"  # Replace USER_ID with the actual user ID you want to update

payload = json.dumps({
  "name": "Rocio Nuevaaa",
  "gender": "female",  # Update other fields as needed
  "email": "updated.email@test.com",
  "status": "inactive"
})

headers = {
  'Authorization': 'Bearer 943789d80546535aef167af0afc0b8abdbc358e76308bafd10ba03f7f331f64e',  # Replace YOUR_TOKEN with your actual GoRest API token
  'Content-Type': 'application/json'
}

response = requests.request("PUT", url, headers=headers, data=payload)

if response.status_code == 200:
    print(f"User with ID {5704661} updated successfully!")
    print(response.text)
else:
    print(f"Failed to update user. Status code: {response.status_code}, Response: {response.text}")
# Out:
# User with ID 5704661 updated successfully!
# {"email":"updated.email@test.com","name":"Rocio Nuevaaa","gender":"female","status":"inactive","id":5707339}

# %%
import requests

url = "https://gorest.co.in/public/v2/users/5704661"  # Replace USER_ID with the actual user ID you want to delete

headers = {
  'Authorization': 'Bearer 943789d80546535aef167af0afc0b8abdbc358e76308bafd10ba03f7f331f64e',  # Replace YOUR_TOKEN with your actual GoRest API token
  'Content-Type': 'application/json'
}

response = requests.request("DELETE", url, headers=headers)

if response.status_code == 204:
    print(f"User with ID {5704661} deleted successfully!")
    print(response.text)
else:
    print(f"Failed to delete user. Status code: {response.status_code}, Response: {response.text}")
# Out:
# Failed to delete user. Status code: 404, Response: {"message":"Resource not found"}
